# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from google.colab.patches import cv2_imshow
import cv2 as cv

# %%
Training_Dataset = pd.read_csv(dir_path + "Training_Dataset.csv",header=None)

# %%
Testing_Dataset = pd.read_csv(dir_path + "Testing_Dataset.csv",header=None)

# %%
# Define Machine Learning model

# %%
flag = np.zeros((540, 540))
